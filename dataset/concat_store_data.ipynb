# %%
import pandas as pd

# %%
df1 = pd.read_csv('store_data_0405.csv', index_col=0)
df2 = pd.read_csv('0405_구의동.csv', index_col=0)

# %%
df = pd.concat([df1, df2], axis=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34186 entries, 0 to 86
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   store         34186 non-null  object
#  1   address       34186 non-null  object
#  2   url           34186 non-null  object
#  3   openhr        34186 non-null  object
#  4   menu          34186 non-null  object
#  5   photo_exists  34186 non-null  int64
#  6   mean_rate     34060 non-null  float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 2.1+ MB

# %%
df = pd.concat([df1, df2], axis=0)
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace=True)
df.to_csv('store_data_0405.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34186 entries, 0 to 34185
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   store         34186 non-null  object
#  1   address       34186 non-null  object
#  2   url           34186 non-null  object
#  3   openhr        34186 non-null  object
#  4   menu          34186 non-null  object
#  5   photo_exists  34186 non-null  int64
#  6   mean_rate     34060 non-null  float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1.8+ MB

# %%
main = pd.read_csv('review_data_0406.csv', index_col=0)
sub = pd.read_csv('review_data_0406(2).csv', index_col=0)

df = pd.concat([main, sub], axis=0)
df
# Out:
#            store_name                            address  taste_score  \
# 0               24시채린             서울특별시 광진구 중곡동 140-3 1층            5
# 1               24시채린             서울특별시 광진구 중곡동 140-3 1층            5
# 2               24시채린             서울특별시 광진구 중곡동 140-3 1층            5
# 3               24시채린             서울특별시 광진구 중곡동 140-3 1층            5
# 4               24시채린             서울특별시 광진구 중곡동 140-3 1층            4
# ...               ...                                ...          ...
# 26673  탕수육참잘하는집탕참-중곡점  서울특별시 광진구 중곡동 162-12 제일빌딩 1층 101호            5
# 26674  탕수육참잘하는집탕참-중곡점  서울특별시 광진구 중곡동 162-12 제일빌딩 1층 101호            5
# 26675  탕수육참잘하는집탕참-중곡점  서울특별시 광진구 중곡동 162-12 제일빌딩 1층 101호            5
# 26676  탕수육참잘하는집탕참-중곡점  서울특별시 광진구 중곡동 162-12 제일빌딩 1층 101호            5
# 26677  탕수육참잘하는집탕참-중곡점  서울특별시 광진구 중곡동 162-12 제일빌딩 1층 101호            5
#
#        quantity_score  delivery_score  \
# 0                   5             5.0
# 1                   5             NaN
# ...

# %%
df.reset_index(drop=True, inplace=True)
df.to_csv('review_data_0406.csv')

# %%
main = pd.read_csv('review_data_0406.csv', index_col=0)
main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35348 entries, 0 to 35347
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   store_name      35348 non-null  object
#  1   address         35348 non-null  object
#  2   taste_score     35348 non-null  int64
#  3   quantity_score  35348 non-null  int64
#  4   delivery_score  34061 non-null  float64
#  5   review          35348 non-null  object
#  6   review_time     35348 non-null  object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 2.2+ MB

# %%
store = pd.read_csv('store_data_0405.csv', index_col=0)
store
# Out:
#          store                           address  \
# 0      동성관-자양점           서울특별시 광진구 자양동 623-18 1층
# 1      동성관-자양점           서울특별시 광진구 자양동 623-18 1층
# 2      동성관-자양점           서울특별시 광진구 자양동 623-18 1층
# 3      동성관-자양점           서울특별시 광진구 자양동 623-18 1층
# 4      동성관-자양점           서울특별시 광진구 자양동 623-18 1층
# ...        ...                               ...
# 36296     청춘한쌈  서울특별시 광진구 구의동 236-23 236-23 103호
# 36297     청춘한쌈  서울특별시 광진구 구의동 236-23 236-23 103호
# 36298     청춘한쌈  서울특별시 광진구 구의동 236-23 236-23 103호
# 36299     청춘한쌈  서울특별시 광진구 구의동 236-23 236-23 103호
# 36300     청춘한쌈  서울특별시 광진구 구의동 236-23 236-23 103호
#
#                                              url         openhr  \
# 0      https://www.yogiyo.co.kr/mobile/#/405486/  10:10 - 20:30
# 1      https://www.yogiyo.co.kr/mobile/#/405486/  10:10 - 20:30
# 2      https://www.yogiyo.co.kr/mobile/#/405486/  10:10 - 20:30
# 3      https://www.yogiyo.co.kr/mobile/#/405486/  10:10 - 20:30
# ...

# %%
store1 = store[['store' , 'address']]
store1.drop_duplicates(inplace=True)
store1.reset_index(drop=True, inplace=True)
store1
# Out:
# /var/folders/x_/s6rt1hw118zdhq387czgy5q40000gn/T/ipykernel_27265/1442781704.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   store1.drop_duplicates(inplace=True)
#            store                              address
# 0        동성관-자양점              서울특별시 광진구 자양동 623-18 1층
# 1          24시채린               서울특별시 광진구 중곡동 140-3 1층
# 2       바로덮밥-건대점            서울특별시 광진구 화양동 111-5 2층 6호
# 3       백억커피-화양점            서울특별시 광진구 화양동 21-1 1층 일부호
# 4      부어치킨-자양고점  서울특별시 광진구 자양동 553-41 자양우성5차아파트 311동
# ..           ...                                  ...
# 681     마라하오-구의점          서울특별시 광진구 구의동 248-135 1층 일부
# 682  레전드고기한상-군자점               서울특별시 광진구 군자동 463-5 2층
# 683   정우의도시락-건대점              서울특별시 광진구 군자동 355-11 2층
# 684   바다회포차-자양본점               서울특별시 광진구 자양동 794-8 1층
# ...

# %%
review = review[['store', 'address', 'taste_score', 'quantity_score', 'delivery_score', 'review', 'review_time']]
review.to_csv('review_data_0406.csv', index=False)

# %%
review = review.merge(store1, on='address', how='left')
review
# Out:
#                       address  taste_score  quantity_score  delivery_score  \
# 0      서울특별시 광진구 중곡동 140-3 1층            5               5             5.0
# 1      서울특별시 광진구 중곡동 140-3 1층            5               5             NaN
# 2      서울특별시 광진구 중곡동 140-3 1층            5               5             NaN
# 3      서울특별시 광진구 중곡동 140-3 1층            5               5             NaN
# 4      서울특별시 광진구 중곡동 140-3 1층            4               4             NaN
# ...                       ...          ...             ...             ...
# 61920  서울특별시 광진구 화양동 18-24 1층            5               5             5.0
# 61921  서울특별시 광진구 화양동 18-24 1층            5               5             5.0
# 61922  서울특별시 광진구 화양동 18-24 1층            5               5             5.0
# 61923  서울특별시 광진구 화양동 18-24 1층            5               5             5.0
# 61924  서울특별시 광진구 화양동 18-24 1층            5               5             5.0
#
# ...

# %%
df5 = pd.read_csv('review_data_0406.csv', index_col=0)
df5
# Out:
#             store                 address  taste_score  quantity_score  \
# 0           24시채린  서울특별시 광진구 중곡동 140-3 1층            5               5
# 1           24시채린  서울특별시 광진구 중곡동 140-3 1층            5               5
# 2           24시채린  서울특별시 광진구 중곡동 140-3 1층            5               5
# 3           24시채린  서울특별시 광진구 중곡동 140-3 1층            5               5
# 4           24시채린  서울특별시 광진구 중곡동 140-3 1층            4               4
# ...           ...                     ...          ...             ...
# 61920  육회바른연어-화양점  서울특별시 광진구 화양동 18-24 1층            5               5
# 61921  육회바른연어-화양점  서울특별시 광진구 화양동 18-24 1층            5               5
# 61922  육회바른연어-화양점  서울특별시 광진구 화양동 18-24 1층            5               5
# 61923  육회바른연어-화양점  서울특별시 광진구 화양동 18-24 1층            5               5
# 61924  육회바른연어-화양점  서울특별시 광진구 화양동 18-24 1층            5               5
#
#        delivery_score                                             review  \
# ...
